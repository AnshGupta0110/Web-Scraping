# %%
from selenium import webdriver 
import requests 
from bs4 import BeautifulSoup
import pandas as pd

link = 'https://stock-pictures.netlify.app/'

# %%
browser = webdriver.Chrome()

# %%
browser.get(link)

# %%
soup = BeautifulSoup(browser.page_source,'html.parser')

# %%
data = []

for sp in soup.find_all('div', class_ = 'container'):
    #print(sp)
        
    link = sp.find('img').get('src')
    tag = list(set(sp.find('div', class_ = 'tags').text[7:].split(" ")))
    
    likes    = int(sp.find('div', class_ = 'likes-comments').find_all('span')[0].text[:-6])
    comments = int(sp.find('div', class_ = 'likes-comments').find_all('span')[1].text[:-9])
    
    data.append([link,' '.join(tag),likes,comments])
    
    #break

# %%
for sp in soup.find_all('div', class_ = 'container'):
    likes    = int(sp.find('div', class_ = 'likes-comments').find_all('span')[0].text[:-6])
    comments = int(sp.find('div', class_ = 'likes-comments').find_all('span')[1].text[:-9])
    print(likes,comments)
    break
# Out:
# 196 55

# %%
data
# Out:
# [['https://cdn.pixabay.com/photo/2022/03/06/05/30/clouds-7050884__480.jpg',
#   'Sky, Atmosphere, Blue Sky Clouds,',
#   196,
#   55],
#  ['https://cdn.pixabay.com/photo/2022/04/07/11/45/bird-7117346__340.jpg',
#   'Bird, Ornithology, Hummingbird',
#   76,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/02/28/15/28/sea-7039471__340.jpg',
#   'Rainfall, Rainbow, Subtropical Sea,',
#   282,
#   106],
#  ['https://cdn.pixabay.com/photo/2022/04/04/02/52/cherry-blossoms-7110279__340.jpg',
#   'Cherry Road, Blossoms, Sakura Japan,',
#   42,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/04/09/18/06/cape-marguerite-7121992__340.jpg',
#   'Marguerite, Plant Cape Flower,',
#   39,
#   15],
#  ['https://cdn.pixabay.com/photo/2021/11/13/23/06/tree-6792528__340.jpg',
#   'Rest Under Tree The Relaxing',
#   522,
#   108],
#  ['https://cdn.pixabay.com/photo/2022/04/07/02/56/cottontail-rabbit-7116707__340.jpg',
#   'Cottontail Rabbit, Grass Wild',
#   51,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/03/19/21/11/crocus-7079550__340.jpg',
#   'Flowers, Plant Crocus, Spring,',
#   135,
#   44],
#  ['https://cdn.pixabay.com/photo/2022/04/09/17/30/coffee-7121939__340.jpg',
#   'Coffee, Table Café, Drink, Vacation,',
#   26,
#   5],
#  ['https://cdn.pixabay.com/photo/2022/03/25/19/24/waterfall-7091641__340.jpg',
#   'Light Waterfall, Nature, Fall, Epic,',
#   96,
#   21],
#  ['https://cdn.pixabay.com/photo/2021/08/25/20/42/field-6574455__340.jpg',
#   'Field, Sunrise, Nature Morning, Dawn,',
#   807,
#   131],
#  ['https://cdn.pixabay.com/photo/2022/04/04/18/03/bird-7111988__340.jpg',
#   'Robin, Bird, Animal Birdwatching,',
#   69,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/04/07/58/seedlings-7110591__340.jpg',
#   'Flowers, Bloom Seedlings, Soil, Spring',
#   42,
#   9],
#  ['https://cdn.pixabay.com/photo/2022/03/23/21/27/road-7087957__340.jpg',
#   'Road, Hills Highway, Countryside,',
#   53,
#   14],
#  ['https://cdn.pixabay.com/photo/2022/03/27/15/03/cityscape-7095358__340.jpg',
#   'Cityscape, Monochrome, City Bridge,',
#   45,
#   13],
#  ['https://cdn.pixabay.com/photo/2022/03/25/17/54/sakura-7091532__340.jpg',
#   'Sakura, Cherry Blossoms, Water Spring,',
#   70,
#   12],
#  ['https://cdn.pixabay.com/photo/2022/04/01/19/03/background-7105471__480.jpg',
#   'Easter, Template, Eggs, Background, Art',
#   5,
#   2],
#  ['https://cdn.pixabay.com/photo/2022/01/31/12/46/bird-6983434__340.jpg',
#   'Indian Bird, Chat, Ornithology, Species',
#   171,
#   53],
#  ['https://cdn.pixabay.com/photo/2022/01/18/16/49/town-6947538__340.jpg',
#   'Winter, Season Village, Night, Town,',
#   109,
#   15],
#  ['https://cdn.pixabay.com/photo/2022/04/09/17/42/flower-7121955__340.jpg',
#   'Bloom Blossom, Pansy, Flower, Viola,',
#   55,
#   36],
#  ['https://cdn.pixabay.com/photo/2021/08/30/21/29/port-6587129__340.jpg',
#   'Vacations Port, Architecture, Lake,',
#   276,
#   49],
#  ['https://cdn.pixabay.com/photo/2022/03/16/02/03/sunflowers-7071449__340.jpg',
#   'Flowers, Plant Sunflowers,',
#   54,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/03/28/18/41/coffee-7098126__340.jpg',
#   'Flowers, Coffee, Morning Spring,',
#   40,
#   10],
#  ['https://cdn.pixabay.com/photo/2022/02/12/06/21/roys-peak-7008528__340.jpg',
#   'Peak, Roys Wanaka, Mountains Lake,',
#   69,
#   19],
#  ['https://cdn.pixabay.com/photo/2021/11/21/21/14/mountain-6815304__340.jpg',
#   'downloads many you everyone. likes. you, for and Thank',
#   197,
#   0],
#  ['https://cdn.pixabay.com/photo/2021/08/22/15/48/nature-6565499__340.jpg',
#   'Beach, Outdoors, Nature, Exploration',
#   272,
#   150],
#  ['https://cdn.pixabay.com/photo/2022/03/03/11/18/nature-7045125__340.jpg',
#   'sunset. Coast Jutland. The Danish Shot during West of',
#   48,
#   11],
#  ['https://cdn.pixabay.com/photo/2022/03/16/21/01/gentoo-penguin-7073391__340.jpg',
#   'Animal Bird, Penguin, Gentoo',
#   93,
#   22],
#  ['https://cdn.pixabay.com/photo/2021/11/26/20/45/lantern-6826698__340.jpg',
#   'Lantern, Sea, Tree Water, Heaven, Beach,',
#   243,
#   31],
#  ['https://cdn.pixabay.com/photo/2022/04/03/05/03/easter-7108066__340.jpg',
#   'Easter, Bunny Easter Spring,',
#   17,
#   10],
#  ['https://cdn.pixabay.com/photo/2018/01/14/23/12/nature-3082832__340.jpg',
#   'formation green rock during daytime on lake trees brown',
#   3098,
#   495],
#  ['https://cdn.pixabay.com/photo/2022/02/27/19/46/tourist-attraction-7037967__340.jpg',
#   'Travel Eiffel Tourist Attraction, Tower,',
#   83,
#   21],
#  ['https://cdn.pixabay.com/photo/2022/04/07/22/23/menhir-7118382__480.jpg',
#   'Standing Menhir, Stones Stones, Clouds,',
#   64,
#   49],
#  ['https://cdn.pixabay.com/photo/2022/01/13/18/05/road-6935773__340.jpg',
#   'Frost, Snow, Winter, Road, Path Trees,',
#   133,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/10/07/03/bird-7122753__340.jpg',
#   'Bird, Woodpecker',
#   28,
#   20],
#  ['https://cdn.pixabay.com/photo/2021/11/25/19/50/tape-6824489__340.jpg',
#   'Music, Classic Cassette, Retro, Tape,',
#   134,
#   20],
#  ['https://cdn.pixabay.com/photo/2022/01/10/15/29/wind-mills-6928590__340.jpg',
#   'Energy, Wind Mills, Power Clouds,',
#   144,
#   101],
#  ['https://cdn.pixabay.com/photo/2022/02/15/07/27/travel-7014427__340.jpg',
#   'Square, Tartini, Travel, Piran Tourism,',
#   70,
#   19],
#  ['https://cdn.pixabay.com/photo/2022/04/11/04/33/easter-eggs-7124718__340.jpg',
#   'Colored Eggs Nest, Easter Eggs,',
#   29,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/02/07/22/27/winter-7000429__340.jpg',
#   'Season, Travel Winter, Outdoors, Nature,',
#   111,
#   24],
#  ['https://cdn.pixabay.com/photo/2022/04/11/09/40/glacier-7125386__340.jpg',
#   'Melting Dying Glacier, Glacier Glaciers,',
#   36,
#   27],
#  ['https://cdn.pixabay.com/photo/2021/11/01/21/31/forest-6761846__340.jpg',
#   'Forest, Jungle, Nature Green, Tropical,',
#   135,
#   22],
#  ['https://cdn.pixabay.com/photo/2022/02/05/08/13/tulip-6994245__340.jpg',
#   'Petals Tulip, Blossom, Bloom, Flower,',
#   92,
#   35],
#  ['https://cdn.pixabay.com/photo/2022/04/07/13/06/flowers-7117461__340.jpg',
#   'Flowers, Petals Pink',
#   62,
#   0],
#  ['https://cdn.pixabay.com/photo/2022/02
# 39  https://cdn.pixabay.com/photo/2022/02/07/22/27...
# 40  https://cdn.pixabay.com/photo/2022/04/11/09/40...
# 41  https://cdn.pixabay.com/photo/2021/11/01/21/31...
# 42  https://cdn.pixabay.com/photo/2022/02/05/08/13...
# 43  https://cdn.pixabay.com/photo/2022/04/07/13/06...
# 44  https://cdn.pixabay.com/photo/2022/02/22/03/22...
# 45  https://cdn.pixabay.com/photo/2021/11/02/21/57...
# 46  https://cdn.pixabay.com/photo/2022/04/09/10/13...
# 47  https://cdn.pixabay.com/photo/2022/03/31/09/25...
#
#                                                  tags  likes  comments
# 0                   Sky, Atmosphere, Blue Sky Clouds,    196        55
# 1                      Bird, Ornithology, Hummingbird     76        20
# 2                 Rainfall, Rainbow, Subtropical Sea,    282       106
# 3                Cherry Road, Blossoms, Sakura Japan,     42        11
# 4                      Marguerite, Plant Cape Flower,     39        15
# 5                        Rest Under Tree The Relaxing    522       108
# 6                       Cottontail Rabbit, Grass Wild     51        10
# 7                      Flowers, Plant Crocus, Spring,    135        44
# 8                Coffee, Table Café, Drink, Vacation,     26         5
# 9                Light Waterfall, Nature, Fall, Epic,     96        21
# 10              Field, Sunrise, Nature Morning, Dawn,    807       131
# 11                  Robin, Bird, Animal Birdwatching,     69        19
# 12             Flowers, Bloom Seedlings, Soil, Spring     42         9
# 13                  Road, Hills Highway, Countryside,     53        14
# 14                Cityscape, Monochrome, City Bridge,     45        13
# 15             Sakura, Cherry Blossoms, Water Spring,     70        12
# 16            Easter, Template, Eggs, Background, Art      5         2
# 17            Indian Bird, Chat, Ornithology, Species    171        53
# 18               Winter, Season Village, Night, Town,    109        15
# 19               Bloom Blossom, Pansy, Flower, Viola,     55        36
# 20                Vacations Port, Architecture, Lake,    276        49
# 21                         Flowers, Plant Sunflowers,     54        21
# 22                   Flowers, Coffee, Morning Spring,     40        10
# 23                 Peak, Roys Wanaka, Mountains Lake,     69        19
# 24  downloads many you everyone. likes. you, for a...    197         0
# 25               Beach, Outdoors, Nature, Exploration    272       150
# 26  sunset. Coast Jutland. The Danish Shot during ...     48        11
# 27                       Animal Bird, Penguin, Gentoo     93        22
# 28           Lantern, Sea, Tree Water, Heaven, Beach,    243        31
# 29                       Easter, Bunny Easter Spring,     17        10
# 30  formation green rock during daytime on lake tr...   3098       495
# 31           Travel Eiffel Tourist Attraction, Tower,     83        21
# 32            Standing Menhir, Stones Stones, Clouds,     64        49
# 33             Frost, Snow, Winter, Road, Path Trees,    133        24
# 34                                   Bird, Woodpecker     28        20
# 35              Music, Classic Cassette, Retro, Tape,    134        20
# 36                  Energy, Wind Mills, Power Clouds,    144       101
# 37            Square, Tartini, Travel, Piran Tourism,     70        19
# 38                    Colored Eggs Nest, Easter Eggs,     29         0
# 39           Season, Travel Winter, Outdoors, Nature,    111        24
# 40           Melting Dying Glacier, Glacier Glaciers,     36        27
# 41            Forest, Jungle, Nature Green, Tropical,    135        22
# 42              Petals Tulip, Blossom, Bloom, Flower,     92        35
# 43                               Flowers, Petals Pink     62         0
# 44                 Passiflora, Flower, Passion Flower     97        66
# 45            Blessing Prayer, Hope, Faith, Religion,    175        57
# 46              Universe, Cosmos Space, Star, Galaxy,     45        40
# 47                   Insect, Macro Dragonfly, Nature,     19         3

# %%
df.to_csv('data.csv', index = False)
